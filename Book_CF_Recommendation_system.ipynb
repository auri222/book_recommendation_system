# %% [markdown]
# <a href="https://colab.research.google.com/github/auri222/book_recommendation_system/blob/master/Book_CF_Recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/zygmuntz/goodbooks-10k/master/books.csv")

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13          authors  original_publication_year  \
# 9995   441019455  9.780441e+12    Ilona Andrews                     2010.0
# 9996  067973371X  9.780680e+12   Robert A. Caro                     1990.0
# 9997  039330762X  9.780393e+12  Patrick O'Brian                     1977.0
# 9998    61711527  9.780062e+12  Peggy Orenstein                     2011.0
# 9999   375700455  9.780376e+12      John Keegan                     1998.0
#
#                                          original_title  ... ratings_count  \
# 9995                                         Bayou Moon  ...         17204
# 9996                                   Means of Ascent   ...         12582
# 9997                              The Mauritius Command  ...          9421
# 9998  Cinderella Ate My Daughter: Dispatches from th...  ...         11279
# 9999                                The First World War  ...          9162
#
#      work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 9995              18856                     1180        105        575
# 9996              12952                      395        303        551
# 9997              10733                      374         11        111
# 9998              11994                     1988        275       1002
# 9999               9700                      364        117        345
#
#       ratings_3  ratings_4  ratings_5  \
# 9995       3538       7860       6778
# 9996       1737       3389       6972
# 9997       1191       4240       5180
# 9998       3765       4577       2375
# 9999       2031       4138       3069
#
#                                               image_url  \
# 9995  https://images.gr-assets.com/books/1307445460m...
# 9996  https://s.gr-assets.com/assets/nophoto/book/11...
# 9997  https://images.gr-assets.com/books/1455373531m...
# 9998  https://images.gr-assets.com/books/1279214118m...
# 9999  https://images.gr-assets.com/books/1403194704m...
#
#                                         small_image_url
# 9995  https://images.gr-assets.com/books/1307445460s...
# 9996  https://s.gr-assets.com/assets/nophoto/book/50...
# 9997  https://images.gr-assets.com/books/1455373531s...
# 9998  https://images.gr-assets.com/books/1279214118s...
# 9999  https://images.gr-assets.com/books/1403194704s...
#
# [5 rows x 23 columns]

# %%
df.head()

# %%
dt = df[['book_id', 'title', 'authors']]

# %%
dt.iloc[30:40,:]
# Out:
#     book_id                                              title  \
# 30       31                                           The Help
# 31       32                                    Of Mice and Men
# 32       33                                Memoirs of a Geisha
# 33       34            Fifty Shades of Grey (Fifty Shades, #1)
# 34       35                                      The Alchemist
# 35       36                          The Giver (The Giver, #1)
# 36       37  The Lion, the Witch, and the Wardrobe (Chronic...
# 37       38                           The Time Traveler's Wife
# 38       39     A Game of Thrones (A Song of Ice and Fire, #1)
# 39       40                                    Eat, Pray, Love
#
#                          authors
# 30              Kathryn Stockett
# 31                John Steinbeck
# 32                 Arthur Golden
# 33                    E.L. James
# 34  Paulo Coelho, Alan R. Clarke
# 35                    Lois Lowry
# 36                    C.S. Lewis
# 37            Audrey Niffenegger
# 38            George R.R. Martin
# 39             Elizabeth Gilbert

# %%
#dt = df.head(20)

# %%
ls = df['title'].head(20).tolist()

# %%
ls
# Out:
# ['The Hunger Games (The Hunger Games, #1)',
#  "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
#  'Twilight (Twilight, #1)',
#  'To Kill a Mockingbird',
#  'The Great Gatsby',
#  'The Fault in Our Stars',
#  'The Hobbit',
#  'The Catcher in the Rye',
#  'Angels & Demons  (Robert Langdon, #1)',
#  'Pride and Prejudice',
#  'The Kite Runner',
#  'Divergent (Divergent, #1)',
#  '1984',
#  'Animal Farm',
#  'The Diary of a Young Girl',
#  'The Girl with the Dragon Tattoo (Millennium, #1)',
#  'Catching Fire (The Hunger Games, #2)',
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)',
#  'The Fellowship of the Ring (The Lord of the Rings, #1)',
#  'Mockingjay (The Hunger Games, #3)']

# %% [markdown]
# ## Data

# %%
# Lấy dữ liệu
books_data = pd.read_csv("https://raw.githubusercontent.com/zygmuntz/goodbooks-10k/master/books.csv")
ratings=pd.read_csv("https://raw.githubusercontent.com/zygmuntz/goodbooks-10k/master/ratings.csv")

# %%
books_data.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
books = books_data[['book_id', 'title', 'original_title', 'authors']]

# %%
books.head()
# Out:
#    book_id                                              title  \
# 0        1            The Hunger Games (The Hunger Games, #1)
# 1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        3                            Twilight (Twilight, #1)
# 3        4                              To Kill a Mockingbird
# 4        5                                   The Great Gatsby
#
#                              original_title                      authors
# 0                          The Hunger Games              Suzanne Collins
# 1  Harry Potter and the Philosopher's Stone  J.K. Rowling, Mary GrandPré
# 2                                  Twilight              Stephenie Meyer
# 3                     To Kill a Mockingbird                   Harper Lee
# 4                          The Great Gatsby          F. Scott Fitzgerald

# %%
# Lấy danh sách 20 quyển sách đầu của tập dữ liệu books => load lên thẻ select dropdown
ls = books['title'].head(20).tolist()

# %%
# Trộn ratings với books dựa trên book_id
books_dt = pd.merge(ratings, books, on='book_id')

# %%
books_dt.head()
# Out:
#    user_id  book_id  rating  \
# 0        1      258       5
# 1       11      258       3
# 2      143      258       4
# 3      242      258       5
# 4      325      258       4
#
#                                                title        original_title  \
# 0  The Shadow of the Wind (The Cemetery of Forgot...  La sombra del viento
# 1  The Shadow of the Wind (The Cemetery of Forgot...  La sombra del viento
# 2  The Shadow of the Wind (The Cemetery of Forgot...  La sombra del viento
# 3  The Shadow of the Wind (The Cemetery of Forgot...  La sombra del viento
# 4  The Shadow of the Wind (The Cemetery of Forgot...  La sombra del viento
#
#                            authors
# 0  Carlos Ruiz Zafón, Lucia Graves
# 1  Carlos Ruiz Zafón, Lucia Graves
# 2  Carlos Ruiz Zafón, Lucia Graves
# 3  Carlos Ruiz Zafón, Lucia Graves
# 4  Carlos Ruiz Zafón, Lucia Graves

# %% [markdown]
# ### Xây dựng ma trận đánh giá

# %%
# ------------------------------------------------------------------------------
# Xây dựng ma trận đánh giá
# Lấy giá trị trung bình các đánh giá của mỗi quyển sách
ratings_mean_count = pd.DataFrame(books_dt.groupby('title')['rating'].mean())

# %%
# Đếm số lượng đánh giá
ratings_mean_count['rating_counts'] = pd.DataFrame(books_dt.groupby('title')['rating'].count())

# %%
# Ma trận đánh giá của từng user đối với từng quyển sách
user_book_rating = books_dt.pivot_table(index='user_id',columns='title', values='rating')

# %% [markdown]
# ### Khởi tạo biến kiểm tra

# %%
book_name = 'Eat, Pray, Love'

# %%
rating_contraint_number = 100

# %%
rank = 10

# %% [markdown]
# ### Tính độ tương dựa trên hệ số tương quan pearson

# %%
book_ratings = user_book_rating[book_name]

# %%
user_book_rating
# Out:
# title     Angels (Walsh Family, #3)  \
# user_id
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# ...                             ...
# 53420                           NaN
# 53421                           NaN
# 53422                           NaN
# 53423                           NaN
# 53424                           NaN
#
# title    "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية  #GIRLBOSS  \
# user_id
# 1                                                     NaN        NaN
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4                                                     NaN        NaN
# 5                                                     NaN        NaN
# ...                                                   ...        ...
# 53420                                                 NaN        NaN
# 53421                                                 NaN        NaN
# 53422                                                 NaN        NaN
# 53423                                                 NaN        NaN
# 53424                                                 NaN        NaN
#
# title    'Salem's Lot  'Tis (Frank McCourt, #2)  \
# user_id
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN
# 5                 NaN                       NaN
# ...               ...                       ...
# 53420             NaN                       NaN
# 53421             NaN                       NaN
# 53422             NaN                       NaN
# 53423             5.0                       NaN
# 53424             NaN                       NaN
#
# title    1,000 Places to See Before You Die  1/4 جرام  \
# user_id
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
# 5                                       NaN       NaN
# ...                                     ...       ...
# 53420                                   NaN       NaN
# 53421                                   NaN       NaN
# 53422                                   NaN       NaN
# 53423                                   NaN       NaN
# 53424                                   NaN       NaN
#
# title    10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 53420                                                  NaN
# 53421                                                  NaN
# 53422                                                  NaN
# 53423                                                  NaN
# 53424                                                  NaN
#
# title    100 Bullets, Vol. 1: First Shot, Last Call  100 Love Sonnets  ...  \
# user_id                                                                ...
# 1                                               NaN               NaN  ...
# 2                                               NaN               NaN  ...
# 3                                               NaN               NaN  ...
# 4                                               NaN               NaN  ...
# 5                                               NaN               NaN  ...
# ...                                             ...               ...  ...
# 53420                                           NaN               NaN  ...
# 53421                                           NaN               NaN  ...
# 53422                                           NaN               NaN  ...
# 53423                                           NaN               NaN  ...
# 53424                                           NaN               NaN  ...
#
# title    محال  مخطوطة بن إسحاق: مدينة الموتى  نادي السيارات  هشت کتاب  هيبتا  \
# user_id
# 1         NaN                            NaN            NaN       NaN    NaN
# 2         NaN                            NaN            NaN       NaN    NaN
# 3         NaN                            NaN            NaN       NaN    NaN
# 4         NaN                            NaN            NaN       NaN    NaN
# 5         NaN                            NaN            NaN       NaN    NaN
# ...       ...                            ...            ...       ...    ...
# 53420     NaN                            NaN            NaN       NaN    NaN
# 53421     NaN                            NaN            NaN       NaN    NaN
# 53422     NaN                            NaN            NaN       NaN    NaN
# 53423     NaN                            NaN            NaN       NaN    NaN
# 53424     NaN                            NaN            NaN       NaN    NaN
#
# title    واحة الغروب  يوتوبيا  ڤيرتيجو  \
# user_id
# 1                NaN      NaN      NaN
# 2                NaN      NaN      NaN
# 3                NaN      NaN      NaN
# 4                NaN      NaN      NaN
# 5                NaN      NaN      NaN
# ...              ...      ...      ...
# 53420            NaN      NaN      NaN
# 53421            NaN      NaN      NaN
# 53422            NaN      NaN      NaN
# 53423            NaN      NaN      NaN
# 53424            NaN      NaN      NaN
#
# title    キスよりも早く1 [Kisu Yorimo Hayaku 1] (Faster than a Kiss #1)  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 53420                                                  NaN
# 53421                                                  NaN
# 53422                                                  NaN
# 53423                                                  NaN
# 53424                                                  NaN
#
# title    美少女戦士セーラームーン新装版 1 [Bishōjo Senshi Sailor Moon Shinsōban 1]
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 53420                                                  NaN
# 53421                                                  NaN
# 53422                                                  NaN
# 53423                                                  NaN
# 53424                                                  NaN
#
# [53424 rows x 9964 columns]

# %%
book_ratings
# Out:
# user_id
# 1        2.0
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 53420    3.0
# 53421    NaN
# 53422    NaN
# 53423    NaN
# 53424    NaN
# Name: Eat, Pray, Love, Length: 53424, dtype: float64

# %%
book_like_this_book = user_book_rating.corrwith(book_ratings, method = "pearson")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_book = pd.DataFrame(book_like_this_book,columns=['Correlation'])

# %%
corr_book['rating_counts'] = ratings_mean_count['rating_counts']

# %%
corr_book
# Out:
#                                                     Correlation  rating_counts
# title
#  Angels (Walsh Family, #3)                             0.059796            263
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية       0.256718            113
# #GIRLBOSS                                              0.039008            195
# 'Salem's Lot                                           0.258105           4433
# 'Tis (Frank McCourt, #2)                              -0.021563            703
# ...                                                         ...            ...
# واحة الغروب                                            0.135101            138
# يوتوبيا                                                0.263448            313
# ڤيرتيجو                                                0.251949            253
# キスよりも早く1 [Kisu Yorimo Hayaku 1] (Faster than a ...    -0.239046             95
# 美少女戦士セーラームーン新装版 1 [Bishōjo Senshi Sailor Moon S...     0.116335            142
#
# [9964 rows x 2 columns]

# %%
 # Xóa giá trị NAN => Do có những user không đánh giá quyển sách
 corr_book.dropna(inplace=True)

# %%
print(corr_book[corr_book['rating_counts']>rating_contraint_number].sort_values('Correlation', ascending=False).head(rank))
# Out:
#                                                     Correlation  rating_counts
# title
# The Minority Report                                         1.0            182
# All Fall Down (Embassy Row, #1)                             1.0            113
# SilverFin (Young Bond, #1)                                  1.0            120
# More Than Human                                             1.0            131
# Shatterproof (The 39 Clues: Cahills vs. Vespers...          1.0            137
# Death Note, Vol. 7: Zero (Death Note, #7)                   1.0            119
# The Eternity Cure (Blood of Eden, #2)                       1.0            200
# The Hydrogen Sonata (Culture #10)                           1.0            143
# Bound by Honor (Born in Blood Mafia Chronicles,...          1.0            107
# All Tomorrow's Parties (Bridge, #3)                         1.0            157

# %% [markdown]
# ### Xây dựng hàm để đưa ra các gợi ý

# %%
def pred_list(book_name, rating_contraint_number, rank):
   book_ratings = user_book_rating[book_name]
   book_like_this_book = user_book_rating.corrwith(book_ratings, method = "pearson")
   corr_book = pd.DataFrame(book_like_this_book,columns=['Correlation'])
   corr_book['rating_counts'] = ratings_mean_count['rating_counts']
   corr_book.dropna(inplace=True)
   lst = corr_book[corr_book['rating_counts']>rating_contraint_number].sort_values('Correlation', ascending=False).head(rank).index.tolist()
   if book_name in lst:
       lst.remove(book_name)
   return lst

# %%
def pred(book_name, rating_contraint_number, rank):
   book_ratings = user_book_rating[book_name]
   book_like_this_book = user_book_rating.corrwith(book_ratings, method = "pearson")
   corr_book = pd.DataFrame(book_like_this_book,columns=['Correlation'])
   corr_book['rating_counts'] = ratings_mean_count['rating_counts']
   corr_book.dropna(inplace=True)
   print(corr_book[corr_book['rating_counts']>rating_contraint_number].sort_values('Correlation', ascending=False).head(rank))

# %% [markdown]
# ### Thử nghiệm

# %%
pred(book_name='Twilight (Twilight, #1)',rating_contraint_number=100,rank=10)
# Out:
#                                                     Correlation  rating_counts
# title
# Twilight (Twilight, #1)                                1.000000          16931
# The Twilight Saga (Twilight, #1-4)                     0.893485            932
# The Twilight Saga Complete Collection  (Twiligh...     0.887020            383
# The Twilight Collection (Twilight, #1-3)               0.869397            427
# Eclipse (Twilight, #3)                                 0.831682           9620
# The Faithful Spy (John Wells, #1)                      0.816161            121
# New Moon (Twilight, #2)                                0.815995           9712
# Twilight: The Graphic Novel, Vol. 1 (Twilight: ...     0.805491            225
# Breaking Dawn (Twilight, #4)                           0.775193           9433
# Twilight: The Graphic Novel, Vol. 2  (Twilight:...     0.759556            124

# %%
ls = pred_list(book_name='Twilight (Twilight, #1)',rating_contraint_number=100,rank=10)
ls
# Out:
# ['The Twilight Saga (Twilight, #1-4)',
#  'The Twilight Saga Complete Collection  (Twilight, #1-4 + 3.5)',
#  'The Twilight Collection (Twilight, #1-3)',
#  'Eclipse (Twilight, #3)',
#  'The Faithful Spy (John Wells, #1)',
#  'New Moon (Twilight, #2)',
#  'Twilight: The Graphic Novel, Vol. 1 (Twilight: The Graphic Novel, #1)',
#  'Breaking Dawn (Twilight, #4)',
#  'Twilight: The Graphic Novel, Vol. 2  (Twilight: The Graphic Novel, #2)']

# %%
len(ls)
# Out:
# 9
